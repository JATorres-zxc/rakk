# %%
import os


os.environ["KERAS_BACKEND"] = "torch"


import numpy as np
import pandas as pd
from keras.layers import LSTM, Dense, Dropout, Normalization, Input
from keras.models import Sequential
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../../.data/lowhigh_2023_2025.csv")
del df["Unnamed: 0"]
del df["Unnamed: 0.1"]
df = df[df["low"] != "NOT AVAILABLE"]
df = df.dropna()
df
# Out:
#               date                          market                 commodity  \
# 0       2024-01-02          Taguig People's Market            sugar (washed)
# 1       2024-01-02                  Dagonoy Market             pechay baguio
# 2       2024-01-02          Marikina Public Market  well-milled rice (local)
# 3       2024-01-02  Guadalupe Public Market/Makati                   tilapia
# 4       2024-01-02  Guadalupe Public Market/Makati             corn (yellow)
# ...            ...                             ...                       ...
# 154001  2025-02-25          Kamuning Public Market                   cabbage
# 154002  2025-02-25          Kamuning Public Market                    tomato
# 154003  2025-02-25          Kamuning Public Market                  eggplant
# 154004  2025-02-25        Muñoz Market/Quezon City                   cabbage
# 154005  2025-02-25            Navotas Agora Market                   tilapia
#
#           low   high
# 0        75.0   80.0
# 1        80.0   90.0
# 2       48.00  48.00
# 3       140.0  150.0
# 4       60.00  80.00
# ...       ...    ...
# 154001   70.0   90.0
# 154002   40.0   60.0
# 154003   90.0  100.0
# 154004   50.0  120.0
# 154005  150.0  160.0
#
# [122584 rows x 5 columns]

# %%
set(df["market"])
# Out:
# {'Agora Public Market/San Juan',
#  'Balintawak (Cloverleaf) Market',
#  'Bicutan Market',
#  'Blumentritt Market',
#  'Cartimar Market',
#  'Commonwealth Market/Quezon City',
#  'Dagonoy Market',
#  'Guadalupe Public Market/Makati',
#  'Kamuning Public Market',
#  'La Huerta Market/Parañaque',
#  'Malabon Central Market',
#  'Mandaluyong Public Market',
#  'Marikina Public Market',
#  'Maypajo Public Market/Caloocan',
#  'Mega Q-mart/Quezon City',
#  'Murphy Public Market',
#  'Muñoz Market/Quezon City',
#  'Muñoz Market/Quezon City\nNavotas Agora Market',
#  'Navotas Agora Market',
#  'New Las Piñas City Public Market',
#  'New Marulas Public Market/Valenzuela',
#  'Obrero Market',
#  'Paco Market',
#  'Pamilihang Lungsod ng Muntinlupa',
#  'Pasay City Market',
#  'Pasig City Mega Market',
#  'Pateros Market',
#  'Pritil Market/Manila',
#  'Quinta Market/Manila',
#  'San Andres Market/Manila',
#  "Taguig People's Market",
#  'Trabajo Market'}

# %%
data_by_commodities = {}

for commodity in set(df["commodity"]):
    # print("[INFO] processing:", commodity)
    data_by_commodities[commodity] = df.loc[df["commodity"] == commodity]

data_by_commodities
# Out:
# {'egg (medium)':               date                            market     commodity  low high
#  13      2024-01-02                    Dagonoy Market  egg (medium)  7.0  8.0
#  21      2024-01-02    Guadalupe Public Market/Makati  egg (medium)  8.0  8.0
#  33      2024-01-02            Kamuning Public Market  egg (medium)  8.5  9.0
#  46      2024-01-02                    Bicutan Market  egg (medium)  8.0  8.5
#  59      2024-01-02      Agora Public Market/San Juan  egg (medium)  8.0  8.5
#  ...            ...                               ...           ...  ...  ...
#  153826  2025-02-25  Pamilihang Lungsod ng Muntinlupa  egg (medium)  7.2  8.0
#  153830  2025-02-25           Mega Q-mart/Quezon City  egg (medium)  7.5  8.5
#  153859  2025-02-25              Navotas Agora Market  egg (medium)  7.2  8.0
#  153880  2025-02-25                       Paco Market  egg (medium)  7.8  8.5
#  153997  2025-02-25    Maypajo Public Market/Caloocan  egg (medium)  9.0  9.0
#
#  [8686 rows x 5 columns],
#  'well-milled rice (local)':               date                                market  \
#  2       2024-01-02                Marikina Public Market
#  6       2024-01-02        Guadalupe Public Market/Makati
#  51      2024-01-02                        Bicutan Market
#  64      2024-01-02          Agora Public Market/San Juan
#  87      2024-01-02                       Cartimar Market
#  ...            ...                                   ...
#  153815  2025-02-25  New Marulas Public Market/Valenzuela
#  153817  2025-02-25                  Navotas Agora Market
#  153821  2025-02-25                  Murphy Public Market
#  153825  2025-02-25              Muñoz Market/Quezon City
#  153829  2025-02-25      Pamilihang Lungsod ng Muntinlupa
#
#                         commodity    low   high
#  2       well-milled rice (local)  48.00  48.00
#  6       well-milled rice (local)  45.00  45.00
#  51      well-milled rice (local)  51.00  52.00
#  64      well-milled rice (local)  46.00  46.00
#  87      well-milled rice (local)  52.00  53.00
#  ...                          ...    ...    ...
#  153815  well-milled rice (local)  46.00  47.00
#  153817  well-milled rice (local)  40.00  45.00
#  153821  well-milled rice (local)  45.00  48.00
#  153825  well-milled rice (local)  48.00  53.00
#  153829  well-milled rice (local)  45.00  48.00
#
#  [7135 rows x 5 columns],
#  'ampalaya':               date                            market commodity    low   high
#  22      2024-01-02    Guadalupe Public Market/Makati  ampalaya  100.0  120.0
#  28      2024-01-02                    Dagonoy Market  ampalaya  100.0  120.0
#  32      2024-01-02            Kamuning Public Market  ampalaya  100.0  120.0
#  44      2024-01-02   Commonwealth Market/Quezon City  ampalaya  110.0  120.0
#  45      2024-01-02                    Bicutan Market  ampalaya  100.0  120.0
#  ...            ...                               ...       ...    ...    ...
#  153982  2025-02-25            Kamuning Public Market  ampalaya  120.0  140.0
#  153990  2025-02-25            Malabon Central Market  ampalaya  100.0  130.0
#  153995  2025-02-25         Mandaluyong Public Market  ampalaya  120.0  130.0
#  153996  2025-02-25  New Las Piñas City Public Market  ampalaya  120.0  125.0
#  153999  2025-02-25        La Huerta Market/Parañaque  ampalaya   90.0  120.0
#
#  [8728 rows x 5 columns],
#  'cabbage':               date                            market commodity    low   high
#  30      2024-01-02            Kamuning Public Market   cabbage  60.00  70.00
#  42      2024-01-02   Commonwealth Market/Quezon City   cabbage  80.00  80.00
#  58      2024-01-02    Guadalupe Public Market/Makati   cabbage  60.00  80.00
#  131     2024-01-02           Mega Q-mart/Quezon City   cabbage  60.00  80.00
#  141     2024-01-02  New Las Piñas City Public Market   cabbage  70.00  75.00
#  ...            ...                               ...       ...    ...    ...
#  153985  2025-02-25    Guadalupe Public Market/Makati   cabbage   50.0   80.0
#  153987  2025-02-25            Malabon Central Market   cabbage   60.0  100.0
#  153992  2025-02-25  New Las Piñas City Public Market   cabbage   85.0   90.0
#  154001  2025-02-25            Kamuning Public Market   cabbage   70.0   90.0
#  154004  2025-02-25          Muñoz Market/Quezon City   cabbage   50.0  120.0
#
#  [515 rows x 5 columns],
#  'frozen pork liempo':               date                            market           commodity  \
#  27368   2024-04-16                    Trabajo Market  frozen pork liempo
#  27381   2024-04-16            Taguig People's Market  frozen pork liempo
#  27446   2024-04-16           Mega Q-mart/Quezon City  frozen pork liempo
#  27460   2024-04-16    Maypajo Public Market/Caloocan  frozen pork liempo
#  27470   2024-04-16                    Bicutan Market  frozen pork liempo
#  ...            ...                               ...                 ...
#  148090  2025-02-06                   Cartimar Market  frozen pork liempo
#  148107  2025-02-06                    Bicutan Market  frozen pork liempo
#  148121  2025-02-06      Agora Public Market/San Juan  frozen pork liempo
#  148131  2025-02-06                    Dagonoy Market  frozen pork liempo
#  148145  2025-02-06  New Las Piñas City Public Market  frozen pork liempo
#
#             low    high
#  27368   270.00  270.00
#  27381   270.00  270.00
#  27446   290.00  300.00
#  27460   285.00  285.00
#  27470   270.00  280.00
#  ...        ...     ...
#  148090  300.00  300.00
#  148107  300.00  300.00
#  148121  350.00  350.00
#  148131  320.00  320.00
#  148145  310.00  330.00
#
#  [2849 rows x 5 columns],
#  'fresh pork liempo':               date                          market          commodity    low  \
#  27324   2024-04-16            Quinta Market/Manila  fresh pork liempo  370.0
#  27332   2024-04-16            Pritil Market/Manila  fresh pork liempo  380.0
#  27382   2024-04-16          Taguig People's Market  fresh pork liempo  340.0
#  27383   2024-04-16                  Trabajo Market  fresh pork liempo  420.0
#  27384   2024-04-16        San Andres Market/Manila  fresh pork liempo  380.0
#  ...            ...                             ...                ...    ...
#  153897  2025-02-25  Maypajo Public Market/Caloocan  fresh pork liempo  410.0
#  153902  2025-02-25      La Huerta Market/Parañaque  fresh pork liempo  420.0
#  153914  2025-02-25       Mandaluyong Public Market  fresh pork liempo  450.0
#  153918  2025-02-25          Marikina Public Market  fresh pork liempo  410.0
#  153920  2025-02-25          Malabon Central Market  fresh pork liempo  430.0
#
#           high
#  27324   390.0
#  27332   400.0
#  27382   350.0
#  27383   420.0
#  27384   390.0
#  ...       ...
#  153897  440.0
#  153902  430.0
#  153914  450.0
#  153918  440.0
#  153920  460.0
#
#  [6802 rows x 5 columns],
#  'sugar (refined)':               date                                market        commodity  \
#  151181  2025-02-17      Pamilihang Lungsod ng Muntinlupa  sugar (refined)
#  151182  2025-02-17                  Navotas Agora Market  sugar (refined)
#  151185  2025-02-17              Muñoz Market/Quezon City  sugar (refined)
#  151189  2025-02-17                  Murphy Public Market  sugar (refined)
#  151195  2025-02-17  New Marulas Public Market/Valenzuela  sugar (refined)
#  151199  2025-02-17                         Obrero Market  sugar (refined)
#  151265  2025-02-17                     Pasay City Market  sugar (refined)
#  151268  2025-02-17          Agora Public Market/San Juan  sugar (refined)
#  151272  2025-02-17        Balintawak (Cloverleaf) Market  sugar (refined)
#  7       88.0
#  8       80.0
#  27      85.0
#  39      96.0
#  ...      ...
#  153899  84.0
#  153903  82.0
#  153912  85.0
#  153916  84.0
#  153931  85.0
#
#  [8692 rows x 5 columns],
#  'galunggong (local)':               date                                market           commodity  \
#  148162  2025-02-07                Pasig City Mega Market  galunggong (local)
#  148168  2025-02-07  New Marulas Public Market/Valenzuela  galunggong (local)
#  148174  2025-02-07                           Paco Market  galunggong (local)
#  148179  2025-02-07                        Trabajo Market  galunggong (local)
#  148187  2025-02-07              San Andres Market/Manila  galunggong (local)
#  ...            ...                                   ...                 ...
#  153816  2025-02-25                  Navotas Agora Market  galunggong (local)
#  153819  2025-02-25                  Murphy Public Market  galunggong (local)
#  153827  2025-02-25      Pamilihang Lungsod ng Muntinlupa  galunggong (local)
#  153831  2025-02-25               Mega Q-mart/Quezon City  galunggong (local)
#  153832  2025-02-25              Muñoz Market/Quezon City  galunggong (local)
#
#             low    high
#  148162  280.00  290.00
#  148168  300.00  300.00
#  148174  260.00  260.00
#  148179  280.00  320.00
#  148187  340.00  340.00
#  ...        ...     ...
#  153816  340.00  340.00
#  153819  360.00  380.00
#  153827  340.00  360.00
#  153831  300.00  320.00
#  153832  280.00  300.00
#
#  [301 rows x 5 columns],
#  'red onion (local)':               date                            market          commodity  \
#  9       2024-01-02                    Dagonoy Market  red onion (local)
#  19      2024-01-02   Commonwealth Market/Quezon City  red onion (local)
#  29      2024-01-02            Kamuning Public Market  red onion (local)
#  53      2024-01-02      Agora Public Market/San Juan  red onion (local)
#  68      2024-01-02                    Bicutan Market  red onion (local)
#  ...            ...                               ...                ...
#  153976  2025-02-25                   Cartimar Market  red onion (local)
#  153980  2025-02-25                    Bicutan Market  red onion (local)
#  153986  2025-02-25    Guadalupe Public Market/Makati  red onion (local)
#  153991  2025-02-25  New Las Piñas City Public Market  red onion (local)
#  154000  2025-02-25            Kamuning Public Market  red onion (local)
#
#            low   high
#  9       190.0  190.0
#  19      160.0  160.0
#  29      150.0  160.0
#  53      160.0  180.0
#  68      160.0  180.0
#  ...       ...    ...
#  153976  130.0  190.0
#  153980  160.0  180.0
#  153986  140.0  180.0
#  153991  170.0  180.0
#  154000  180.0  180.0
#
#  [8724 rows x 5 columns],
#  'cabbage (scorpio)':               date                                market          commodity  \
#  1675    2024-01-10      New Las Piñas City Public Market  cabbage (scorpio)
#  1688    2024-01-10                        Pateros Market  cabbage (scorpio)
#  1697    2024-01-10                     Pasay City Market  cabbage (scorpio)
#  1710    2024-01-10                Pasig City Mega Market  cabbage (scorpio)
#  1714    2024-01-10                    Blumentritt Market  cabbage (scorpio)
#  ...            ...                                   ...                ...
#  147798  2025-02-06                  Navotas Agora Market  cabbage (scorpio)
#  147802  2025-02-06  New Marulas Public Market/Valenzuela  cabbage (scorpio)
#  147919  2025-02-06                    Blumentritt Market  cabbage (scorpio)
#  147926  2025-02-06                       Cartimar Market  cabbage (scorpio)
#  147961  2025-02-06        Balintawak (Cloverleaf) Market  cabbage (scorpio)
#
#             low    high
#  1675     60.00   70.00
#  1688     70.00   80.00
#  1697     60.00   60.00
#  1710     60.00   60.00
#  1714     60.00   70.00
#  ...        ...     ...
#  147798  100.00  120.00
#  147802   80.00   90.00
#  147919   85.00   85.00
#  147926   80.00   90.00
#  147961   80.00   80.00
#
#  [3717 rows x 5 columns],
#  'pechay baguio':               date                           market      commodity   low  high
#  1       2024-01-02                   Dagonoy Market  pechay baguio  80.0  90.0
#  37      2024-01-02           Kamuning Public Market  pechay baguio  60.0  80.0
#  40      2024-01-02   Guadalupe Public Market/Makati  pechay baguio  60.0  80.0
#  41      2024-01-02  Commonwealth Market/Quezon City  pechay baguio  90.0  90.0
#  54      2024-01-02     Agora Public Market/San Juan  pechay baguio  40.0  70.0
#  ...            ...                              ...            ...   ...   ...
#  148513  2025-02-07          Mega Q-mart/Quezon City  pechay baguio  45.0  80.0
#  148517  2025-02-07   Maypajo Public Market/Caloocan  pechay baguio  60.0  80.0
#  148525  2025-02-07           Marikina Public Market  pechay baguio  70.0  90.0
#  148529  2025-02-07        Mandaluyong Public Market  pechay baguio  80.0  80.0
#  148533  2025-02-07           Malabon Central Market  pechay baguio  80.0  90.0
#
#  [8306 rows x 5 columns],
#  'corn (yellow)':               date                           market      commodity     low  \
#  4       2024-01-02   Guadalupe Public Market/Makati  corn (yellow)   60.00
#  49      2024-01-02                   Bicutan Market  corn (yellow)   60.00
#  62      2024-01-02     Agora Public Market/San Juan  corn (yellow)   60.00
#  72      2024-01-02  Commonwealth Market/Quezon City  corn (yellow)   60.00
#  85      2024-01-02                  Cartimar Market  corn (yellow)   60.00
#  ...            ...                              ...            ...     ...
#  148014  2025-02-06               Blumentritt Market  corn (yellow)   85.00
#  148016  2025-02-06     Agora Public Market/San Juan  corn (yellow)   80.00
#  148029  2025-02-06   Balintawak (Cloverleaf) Market  corn (yellow)   60.00
#  148031  2025-02-06                   Bicutan Market  corn (yellow)   60.00
#  148155  2025-02-06                   Pateros Market  corn (yellow)  120.00
#
#            high
#  4        80.00
#  49       70.00
#  62       70.00
#  72       60.00
#  85       75.00
#  ...        ...
#  148014   90.00
#  148016   80.00
#  148029   60.00
#  148031   80.00
#  148155  120.00
#
#  [7377 rows x 5 columns],
#  'eggplant':               date                            market commodity    low   high
#  148634  2025-02-08      Agora Public Market/San Juan  eggplant  100.0  120.0
#  148635  2025-02-08   Commonwealth Market/Quezon City  eggplant   70.0  100.0
#  148641  2025-02-08    Balintawak (Cloverleaf) Market  eggplant   50.0   80.0
#  148645  2025-02-08                   Cartimar Market  eggplant  100.0  140.0
#  148690  2025-02-08                 Pasay City Market  eggplant   80.0  120.0
#  ...            ...                               ...       ...    ...    ...
#  153983  2025-02-25          Muñoz Market/Quezon City  eggplant   60.0   80.0
#  153989  2025-02-25            Malabon Central Market  eggplant   80.0  120.0
#  153994  2025-02-25  New Las Piñas City Public Market  eggplant  100.0  105.0
#  153998  2025-02-25        La Huerta Market/Parañaque  eggplant   70.0   80.0
#  154003  2025-02-25            Kamuning Public Market  eggplant   90.0  100.0
#
#  [420 rows x 5 columns],
#  'tomato':               date                            market commodity   low  high
#  12      2024-01-02                    Dagonoy Market    tomato  70.0  80.0
#  23      2024-01-02    Guadalupe Public Market/Makati    tomato  60.0  80.0
#  31      2024-01-02            Kamuning Public Market    tomato  60.0  80.0
#  43      2024-01-02   Commonwealth Market/Quezon City    tomato  60.0  80.0
#  56      2024-01-02      Agora Public Market/San Juan    tomato  70.0  80.0
#  ...            ...                               ...       ...   ...   ...
#  153978  2025-02-25                   Cartimar Market    tomato  55.0  65.0
#  153984  2025-02-25    Guadalupe Public Market/Makati    tomato  40.0  40.0
#  153988  2025-02-25            Malabon Central Market    tomato  40.0  60.0
#  153993  2025-02-25  New Las Piñas City Public Market    tomato  60.0  60.0
#  154002  2025-02-25            Kamuning Public Market    tomato  40.0  60.0
#
#  [8728 rows x 5 columns],
#  'cabbage (wonderball)':               date                            market             commodity  \
#  1771    2024-01-10                   Cartimar Market  cabbage (wonderball)
#  1799    2024-01-10  Pamilihang Lungsod ng Muntinlupa  cabbage (wonderball)
#  1833    2024-01-10                       Paco Market  cabbage (wonderball)
#  1874    2024-01-10    Maypajo Public Market/Caloocan  cabbage (wonderball)
#  1932    2024-01-10                    Trabajo Market  cabbage (wonderball)
#  ...            ...                               ...                   ...
#  147796  2025-02-06              Murphy Public Market  cabbage (wonderball)
#  147849  2025-02-06              Navotas Agora Market  cabbage (wonderball)
#  147866  2025-02-06           Mega Q-mart/Quezon City  cabbage (wonderball)
#  147927  2025-02-06                   Cartimar Market  cabbage (wonderball)
#  147934  2025-02-06   Commonwealth Market/Quezon City  cabbage (wonderball)
#
#             low    high
#  1771     35.00   35.00
#  1799     50.00   50.00
#  1833     50.00   60.00
#  1874     50.00   60.00
#  1932     40.00   50.00
#  ...        ...     ...
#  147796  100.00  120.00
#  147849  100.00  120.00
#  147866   70.00   70.00
#  147927   70.00   70.00
#  147934   90.00  100.00
#
#  [3473 rows x 5 columns],
#  'corn (white)':               date                            market     commodity     low  \
#  125     2024-01-02  Pamilihang Lungsod ng Muntinlupa  corn (white)   80.00
#  138     2024-01-02            Malabon Central Market  corn (white)   80.00
#  280     2024-01-02            Taguig People's Market  corn (white)  120.00
#  371     2024-01-03                    Bicutan Market  corn (white)   80.00
#  480     2024-01-03            Taguig People's Market  corn (white)  120.00
#  ...            ...                               ...           ...     ...
#  147042  2025-02-05          Muñoz Market/Quezon City  corn (white)  120.00
#  147069  2025-02-05           Mega Q-mart/Quezon City  corn (white)   80.00
#  147654  2025-02-06    Guadalupe Public Market/Makati  corn (white)  100.00
#  147827  2025-02-06          Muñoz Market/Quezon City  corn (white)  120.00
#  147848  2025-02-06           Mega Q-mart/Quezon City  corn (white)   80.00
#
#            high
#  125      80.00
#  138      80.00
#  280     120.00
#  371      80.00
#  480     120.00
#  ...        ...
#  147042  120.00
#  147069   80.00
#  147654  120.00
#  147827  120.00
#  147848   80.00
#
#  [1699 rows x 5 columns],
#  'galunggong':               date                           market   commodity     low  \
#  34      2024-01-02           Kamuning Public Market  galunggong  240.00
#  70      2024-01-02     Agora Public Market/San Juan  galunggong  300.00
#  82      2024-01-02                  Cartimar Market  galunggong  280.00
#  112     2024-01-02           Marikina Public Market  galunggong  240.00
#  134     2024-01-02          Mega Q-mart/Quezon City  galunggong  220.00
#  ...            ...                              ...         ...     ...
#  147890  2025-02-06           Pasig City Mega Market  galunggong  280.00
#  148002  2025-02-06  Commonwealth Market/Quezon City  galunggong  260.00
#  148004  2025-02-06                  Cartimar Market  galunggong  260.00
#  148012  2025-02-06               Blumentritt Market  galunggong  350.00
#  148018  2025-02-06     Agora Public Market/San Juan  galunggong  340.00
#
#            high
#  34      280.00
#  70      320.00
#  82      300.00
#  112     250.00
#  134     260.00
#  ...        ...
#  147890  290.00
#  148002  260.00
#  148004  280.00
#  148012  350.00
#  148018  350.00
#
#  [5768 rows x 5 columns],
#  'frozen pork kasim/pigue':               date                            market                commodity  \
#  27374   2024-04-16                    Trabajo Market  frozen pork kasim/pigue
#  27399   2024-04-16            Taguig People's Market  frozen pork kasim/pigue
#  27432   2024-04-16      Agora Public Market/San Juan  frozen pork kasim/pigue
#  27434   2024-04-16    Maypajo Public Market/Caloocan  frozen pork kasim/pigue
#  27441   2024-04-16           Mega Q-mart/Quezon City  frozen pork kasim/pigue
#  ...            ...                               ...                      ...
#  148061  2025-02-06            Taguig People's Market  frozen pork kasim/pigue
#  148094  2025-02-06                   Cartimar Market  frozen pork kasim/pigue
#  148104  2025-02-06      Agora Public Market/San Juan  frozen pork kasim/pigue
#  148134  2025-02-06                    Dagonoy Market  frozen pork kasim/pigue
#  148141  2025-02-06  New Las Piñas City Public Market  frozen pork kasim/pigue
#
#             low    high
#  27374   230.00  230.00
#  27399   250.00  250.00
#  27432   260.00  270.00
#  27434   270.00  270.00
#  27441   260.00  270.00
#  ...        ...     ...
#  148061  240.00  240.00
#  148094  240.00  250.00
#  148104  280.00  280.00
#  148134  280.00  280.00
#  148141  230.00  260.00
#
#  [2998 rows x 5 columns],
#  'tilapia':               date                            market commodity    low   high
#  3       2024-01-02    Guadalupe Public Market/Makati   tilapia  140.0  150.0
#  15      2024-01-02                    Dagonoy Market   tilapia  150.0  160.0
#  35      2024-01-02            Kamuning Public Market   tilapia  150.0  160.0
#  48      2024-01-02                    Bicutan Market   tilapia  130.0  140.0
#  60      2024-01-02      Agora Public Market/San Juan   tilapia  130.0  140.0
#  ...            ...                               ...       ...    ...    ...
#  153814  2025-02-25           Mega Q-mart/Quezon City   tilapia  130.0  140.0
#  153820  2025-02-25              Murphy Public Market   tilapia  150.0  160.0
#  153824  2025-02-25          Muñoz Market/Quezon City   tilapia  150.0  160.0
#  153828  2025-02-25  Pamilihang Lungsod ng Muntinlupa   tilapia  140.0  150.0
#  154005  2025-02-25              Navotas Agora Market   tilapia  150.0  160.0
#
#  [8704 rows x 5 columns]}

# %%
df_scorpio = data_by_commodities["cabbage (scorpio)"]
df_scorpio_pateros = df_scorpio[df_scorpio["market"] == "Pateros Market"]
x = pd.to_datetime(df_scorpio_pateros["date"])
low = pd.to_numeric(df_scorpio_pateros["low"])
high = pd.to_numeric(df_scorpio_pateros["high"])

plt.figure(figsize=(30, 6))
plt.xticks(rotation=45)
plt.plot(x, low, "o-b", x, high, "o-r")
plt.legend(["low", "high"])
df_scorpio_pateros
# Out:
#               date          market          commodity    low    high
# 1688    2024-01-10  Pateros Market  cabbage (scorpio)  70.00   80.00
# 2074    2024-01-11  Pateros Market  cabbage (scorpio)  70.00   80.00
# 2446    2024-01-12  Pateros Market  cabbage (scorpio)  70.00   80.00
# 2990    2024-01-15  Pateros Market  cabbage (scorpio)  70.00   80.00
# 3394    2024-01-16  Pateros Market  cabbage (scorpio)  70.00   80.00
# ...            ...             ...                ...    ...     ...
# 145732  2025-02-01  Pateros Market  cabbage (scorpio)  80.00  100.00
# 146191  2025-02-03  Pateros Market  cabbage (scorpio)  80.00  100.00
# 146930  2025-02-04  Pateros Market  cabbage (scorpio)  80.00  100.00
# 147134  2025-02-05  Pateros Market  cabbage (scorpio)  80.00  100.00
# 147591  2025-02-06  Pateros Market  cabbage (scorpio)  80.00  100.00
#
# [281 rows x 5 columns]

# %%
df_train = df_scorpio_pateros[["low", "high"]].iloc[1:]
df_train = df_train.apply(pd.to_numeric)
train_x = []
train_y = []
train_n_future = 1
train_n_past = 13

for ith in range(0, df_train.shape[0], train_n_past + train_n_future):
    tail = ith - 1 + train_n_past
    train_x.append(df_train.iloc[ith:tail].to_numpy())
    train_y.extend(df_train.iloc[tail:tail + train_n_future, 0:df_train.shape[1] - 1].to_numpy())

df_train.shape[0]
# Out:
# 280

# %%
train_x = np.array(train_x)
train_y = np.array(train_y)
train_x.shape, train_y.shape
# Out:
# ((20, 12, 2), (20, 1))

# %%
low_mean = np.mean([low, high])
low_var = np.std([low, high])

model = Sequential()
model.add(Input(shape=(train_x.shape[1], train_x.shape[2])))
model.add(Normalization(mean=low_mean, variance=low_var))
model.add(LSTM(128, activation="relu", return_sequences=True))
model.add(LSTM(64, activation="sigmoid", return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(train_y.shape[1]))
model.add(Normalization(mean=low_mean, variance=low_var, invert=True))

model.compile(optimizer="adam", loss="mse")
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 12, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 12, 128)        │        67,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_1 (Normalization) │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 116,545 (455.25 KB)
#  Trainable params: 116,545 (455.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = model.fit(train_x, train_y, epochs=100, batch_size=16, validation_split=0.1, verbose=0)
plt.plot(hist.history["loss"], label="Loss")
plt.plot(hist.history["val_loss"], label="Validation loss")
plt.legend()

# %%
days_to_predict = 5
date = pd.to_datetime(df.iloc[df.shape[0] - 1]["date"])
dates = [date + pd.Timedelta(days=ith) for ith in range(days_to_predict)]
prices = model.predict(train_x[-days_to_predict:])
plt.figure(figsize=(10, 6))
plt.plot(dates, prices, "o-")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
